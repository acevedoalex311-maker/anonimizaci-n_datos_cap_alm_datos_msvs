# %% [markdown]
# # Caso 3 - Navegación web

# %% [markdown]
# ## Importación de librerías

# %%
from urllib.parse import urlparse
import os
import glob
import hashlib
import kagglehub
import pandas as pd
import numpy as np

# %% [markdown]
# ## Llamado del df

# %%
# download the latest version – returns the path to the downloaded files
path = kagglehub.dataset_download("shawon10/browser-history")
print("Path to dataset files:", path)

if os.path.isdir(path):
    csv_files = glob.glob(os.path.join(path, "*.csv"))
else:
    # if path ends in .zip you can unzip it yourself
    import zipfile
    with zipfile.ZipFile(path) as z:
        z.extractall(os.path.dirname(path))
    csv_files = glob.glob(os.path.join(os.path.dirname(path), "*.csv"))

print("Found CSV files:", csv_files)

# load one (or more) into a DataFrame
df = pd.read_csv(csv_files[0])       
df.columns = [
    "url",
    "first_visit_time",
    "last_visit_time",
    "click_counts",
    "frequency"
]
df.head()
# Out:
# Path to dataset files: C:\Users\PC\.cache\kagglehub\datasets\shawon10\browser-history\versions\1
# Found CSV files: ['C:\\Users\\PC\\.cache\\kagglehub\\datasets\\shawon10\\browser-history\\versions\\1\\TestingHistory.csv', 'C:\\Users\\PC\\.cache\\kagglehub\\datasets\\shawon10\\browser-history\\versions\\1\\TrainingHistory.csv']
#                                                  url  first_visit_time  \
# 0            https://drive.google.com/drive/my-drive        1511916240
# 1                       http://localhost/phpmyadmin/        1519419120
# 2                           https://www.youtube.com/        1515287460
# 3  https://console.starter-ca-central-1.openshift...        1511746560
# 4  https://console.starter-ca-central-1.openshift...        1509489720
#
#    last_visit_time  click_counts  frequency
# 0       1520808300            28      30912
# 1       1520778600            16      13232
# 2       1520799060            22      12375
# 3       1520777880            22       9830
# 4       1520043900            20       9570

# %% [markdown]
# ### Proceso de anonimización

# %%
navhis_df = df.copy()


# --- 1. AGREGACIÓN Y SUPRESIÓN ---
# agregación temporal + supresión de timestamps (o sea restar los timestamps)
navhis_df["time_on_page"] = (
    navhis_df["last_visit_time"] - 
    navhis_df["first_visit_time"]
)

navhis_df.drop(
    columns=["first_visit_time", "last_visit_time"], 
    inplace=True
)
# --- 2. PERTURBACIÓN ---
# Perturbación por redondeo (reducción de precisión)
navhis_df["frequency"] = (
    navhis_df["frequency"] // 10
) * 10

# --- 2. GENERALIZACIÓN ---
# Generalización de URL (quedarse solo con dominio)
def extract_domain(url):
    parsed = urlparse(url)
    return f"{parsed.scheme}://{parsed.netloc}"

navhis_df["url"] = navhis_df["url"].apply(extract_domain)

navhis_df.head()
# Out:
#                                                  url  click_counts  frequency  \
# 0                           https://drive.google.com            28      30910
# 1                                   http://localhost            16      13230
# 2                            https://www.youtube.com            22      12370
# 3  https://console.starter-ca-central-1.openshift...            22       9830
# 4  https://console.starter-ca-central-1.openshift...            20       9570
#
#    time_on_page
# 0       8892060
# 1       1359480
# 2       5511600
# 3       9031320
# 4      10554180

# %% [markdown]
# ### Comparación de ambos df

# %%
df.head(10)
# Out:
#                                                  url  first_visit_time  \
# 0            https://drive.google.com/drive/my-drive        1511916240
# 1                       http://localhost/phpmyadmin/        1519419120
# 2                           https://www.youtube.com/        1515287460
# 3  https://console.starter-ca-central-1.openshift...        1511746560
# 4  https://console.starter-ca-central-1.openshift...        1509489720
# 5                                  http://daler.org/        1520027280
# 6  http://ruetoj-ruetoj.193b.starter-ca-central-1...        1517408760
# 7  http://ruetoc-ruetoc.193b.starter-ca-central-1...        1508093880
# 8                       https://github.com/shawon100        1516319760
# 9  https://myaccount.laxmicoin.com/register?ref=l...        1520364660
#
#    last_visit_time  click_counts  frequency
# 0       1520808300            28      30912
# 1       1520778600            16      13232
# 2       1520799060            22      12375
# 3       1520777880            22       9830
# 4       1520043900            20       9570
# 5       1520780760             5       6270
# 6       1520783100            11       5955
# 7       1520340120            22       5898
# 8       1520544900            24       5539
# 9       1520422500             4       5513

# %%
navhis_df.head(10)
# Out:
#                                                  url  click_counts  frequency  \
# 0                           https://drive.google.com            28      30910
# 1                                   http://localhost            16      13230
# 2                            https://www.youtube.com            22      12370
# 3  https://console.starter-ca-central-1.openshift...            22       9830
# 4  https://console.starter-ca-central-1.openshift...            20       9570
# 5                                   http://daler.org             5       6270
# 6  http://ruetoj-ruetoj.193b.starter-ca-central-1...            11       5950
# 7  http://ruetoc-ruetoc.193b.starter-ca-central-1...            22       5890
# 8                                 https://github.com            24       5530
# 9                    https://myaccount.laxmicoin.com             4       5510
#
#    time_on_page
# 0       8892060
# 1       1359480
# 2       5511600
# 3       9031320
# 4      10554180
# 5        753480
# 6       3374340
# 7      12246240
# 8       4225140
# 9         57840
